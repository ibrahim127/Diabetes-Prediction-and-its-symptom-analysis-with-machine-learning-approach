# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

from sklearn.svm import SVC

from pandas import DataFrame

# %%
# Read data in the excel file
df = pd.read_csv('mona.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
# Get min, max and average of the age
print('Min age: ', min(df['Age']))
print('Max age: ', max(df['Age']))
print('Average age: ', df['Age'].mean())
# Out:
# Min age:  21
# Max age:  81
# Average age:  33.240885416666664

# %%
df = df.drop(df.index[df['Age'] > 30])
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# 5                       0.201   30        0
# 6                       0.248   26        1
# 7                       0.134   29        0
# 10                      0.191   30        0
# ..                        ...  ...      ...
# 758                     0.197   26        0
# 760                     0.766   22        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 767                     0.315   23        0
#
# [417 rows x 9 columns]

# %%
df.to_csv(r'g1.csv')

# %%
# Read data in the excel file
data = pd.read_csv('g1.csv')
data
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0             3            1       89             66             23       94
# 1             5            5      116             74              0        0
# 2             6            3       78             50             32       88
# 3             7           10      115              0              0        0
# 4            10            4      110             92              0        0
# ..          ...          ...      ...            ...            ...      ...
# 412         758            1      106             76              0        0
# 413         760            2       88             58             26       16
# 414         764            2      122             70             27        0
# 415         765            5      121             72             23      112
# 416         767            1       93             70             31        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    28.1                     0.167   21        0
# 1    25.6                     0.201   30        0
# 2    31.0                     0.248   26        1
# 3    35.3                     0.134   29        0
# 4    37.6                     0.191   30        0
# ..    ...                       ...  ...      ...
# 412  37.5                     0.197   26        0
# 413  28.4                     0.766   22        0
# 414  36.8                     0.340   27        0
# 415  26.2                     0.245   30        0
# 416  30.4                     0.315   23        0
#
# [417 rows x 10 columns]

# %%
print('Max Glucose: ', max(data['Glucose']))
# Out:
# Max Glucose:  199

# %%
data_g1 = data.loc[data['Glucose'] == 199]
data_g1
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 365         661            1      199             76             43        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 365  42.9                     1.394   22        1

# %%
# a simple line plot
data_g1.plot(kind='bar', grid = True,figsize = (20,10))
# Out:
# <AxesSubplot:>
