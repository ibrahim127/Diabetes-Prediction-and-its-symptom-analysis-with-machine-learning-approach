# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, make_scorer

from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import pickle

# %%
df = pd.read_csv('mona.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Check Balanced data
sns.countplot(x ='Outcome', data = df)
plt.title('Balanced Data')
# Out:
# Text(0.5, 1.0, 'Balanced Data')

# %%
# Percentage of patients have and do not have dibetices
df['Outcome'].value_counts()/df.shape[0]*100
# Out:
# 0    65.104167
# 1    34.895833
# Name: Outcome, dtype: float64

# %%
# Create a plot to display the percentage of the positive and negative diabeticse 
labels = ['Negative','Positive']
values = df['Outcome'].value_counts().values
print(values)
plt.pie(values, labels=labels, autopct='%1.0f%%')
plt.title('Diabetes Patients Percentage')
plt.show()
# Out:
# [500 268]

# %%
# Display age distribution based on diabetics
sns.distplot(df[df['Outcome'] == 0]['Age'], label='Do not have diabetes')
sns.distplot(df[df['Outcome'] == 1]['Age'], label = 'Have diabetes')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution based on diabetes')
plt.legend()
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# nb = df['Outcome'].value_counts(0)
# b = df['Outcome'].value_counts(1)
# print(nb)
# print(b)

# %%
# Get min, max and average of the age
print('Min age: ', min(df['Age']))
print('Max age: ', max(df['Age']))
print('Average age: ', df['Age'].mean())
# Out:
# Min age:  21
# Max age:  81
# Average age:  33.240885416666664

# %%
# Correlation map
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot = True) 
plt.show()

# %%
# Display Pregnancies distribution
df['Pregnancies'].plot(kind = 'hist', title = 'Pregnancies Distribution on Dataset', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')

plt.legend()
plt.show()

# %%
# Display Pregnancies distribution based on Diabetics
fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['Pregnancies'], label='Do not have Diabetics', ax = axis1)
ax.set(title='People Do Not Have Diabetics')
ax.set(xlabel='Values')

ax = sns.distplot(df[df['Outcome'] == 1]['Pregnancies'], label = 'Have Diabetics', ax = axis2)
ax.set(title='People Have Diabetics')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display Glucose distribution
df['Glucose'].plot(kind = 'hist', title = 'Glucose distribution on Dataset', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display Glucose distribution based on Diabetics
fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))
ax = sns.distplot(df[df['Outcome'] == 0]['Glucose'], label='Do not have Diabetes', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')
ax = sns.distplot(df[df['Outcome'] == 1]['Glucose'], label = 'Have Diabetes', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')
plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display blood pressure distribution
df['BloodPressure'].plot(kind = 'hist', title = 'Blood Pressure in mm Hg', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display BloodPressure distribution based on Diabetics
fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['BloodPressure'], label='Do not have Diabetes', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')

ax = sns.distplot(df[df['Outcome'] == 1]['BloodPressure'], label = 'Have Diabetes', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display SkinThickness distribution
df['SkinThickness'].plot(kind = 'hist', title = 'SkinThickness Distribution on Dataset', figsize = (8, 6))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display SkinThickness distribution based on Diabetics
fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['SkinThickness'], label='Do not have Diabetes', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')
ax = sns.distplot(df[df['Outcome'] == 1]['SkinThickness'], label = 'Have Diabetes', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display Insulin distribution
df['Insulin'].plot(kind = 'hist', title = 'Insulin Distribution on Dataset', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display Insulin distribution based on Diabetics

fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['Insulin'], label='Do not have Diabetes', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')


ax = sns.distplot(df[df['Outcome'] == 1]['Insulin'], label = 'Have Diabetes', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display BMI distribution
df['BMI'].plot(kind = 'hist', title = 'BMI Distribution on Dataset', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display BMI distribution based on Diabetics

fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['BMI'], label='Do not have Diabetes', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')

ax = sns.distplot(df[df['Outcome'] == 1]['BMI'], label = 'Have Diabetes', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display DiabetesPedigreeFunction distribution
df['DiabetesPedigreeFunction'].plot(kind = 'hist', title = 'DiabetesPedigreeFunction distribution on Dataset', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display DiabetesPedigreeFunction distribution based on Diabetics

fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['DiabetesPedigreeFunction'], label='Do not have Diabetes', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')

ax = sns.distplot(df[df['Outcome'] == 1]['DiabetesPedigreeFunction'], label = 'Have Diabetes', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Display Age distribution
df['Age'].plot(kind = 'hist', title = 'Age distribution On Dataset', figsize = (8, 5))
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
# Display Age distribution based on Diabetics

fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 8))

ax = sns.distplot(df[df['Outcome'] == 0]['Age'], label='Do not have Diabetics', ax = axis1)
ax.set(title='People Do Not Have Diabetes')
ax.set(xlabel='Values')

ax = sns.distplot(df[df['Outcome'] == 1]['Age'], label = 'Have Diabetics', ax = axis2)
ax.set(title='People Have Diabetes')
ax.set(xlabel='Values')

plt.show()
# Out:
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# C:\Users\Hp\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Initialize data and outcome
target = df['Outcome']
features = df.drop(['Outcome'], axis = 1)

# %%
# Split the data into training set and testing set
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 0)

# %%
# Train and evaluate model
def fit_eval_model(model, train_features, y_train, test_features, y_test):
    
    results = {}
    
    # Train the model
    model.fit(train_features, y_train)
    
    # Test the model
    train_predicted = model.predict(train_features)
    test_predicted = model.predict(test_features)
    
    # Classification report and Confusion Matrix
    results['classification_report'] = classification_report(y_test, test_predicted)
    results['confusion_matrix'] = confusion_matrix(y_test, test_predicted)
        
    return results

# %%
# Initialize the models
sv = SVC()
rf = RandomForestClassifier()
knn = KNeighborsClassifier()
nb = GaussianNB()


# Fit and evaluate models
results = {}
for cls in [sv,rf,knn,nb]:
    cls_name = cls.__class__.__name__
    results[cls_name] = {}
    results[cls_name] = fit_eval_model(cls, X_train, y_train, X_test, y_test)

# %%
# Print classifiers results
for result in results:
    print (result)
    print()
    for i in results[result]:
        print (i, ':')
        print(results[result][i])
        print()
    print ('----------------------------------------------------')
    print()
# Out:
# SVC
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86       107
#            1       0.73      0.51      0.60        47
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.71      0.73       154
# weighted avg       0.78      0.79      0.78       154
#
#
# confusion_matrix :
# [[98  9]
#  [23 24]]
#
# ----------------------------------------------------
#
# RandomForestClassifier
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       107
#            1       0.69      0.66      0.67        47
#
#     accuracy                           0.81       154
#    macro avg       0.77      0.76      0.77       154
# weighted avg       0.80      0.81      0.80       154
#
#
# confusion_matrix :
# [[93 14]
#  [16 31]]
#
# ----------------------------------------------------
#
# ...

# %%
input_data = (7,196,90,0,0,39.8,0.451,41) #must input 8 parameters

# changing input data to a numpy array
numpy_array = np.asarray(input_data)

# change the input data to a numpy array
numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = numpy_array.reshape(1,-1)

prediction = cls.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Diabetes')
else:
  print('The Person has Diabetes')
# Out:
# [1]
# The Person has Diabetes

# %%
if(prediction[0]==1):
    if(numpy_array[7]<35 and numpy_array[1]<100):
        print("The person has in type 1")
    elif(numpy_array[7]>=35 and numpy_array[1]>=100 and numpy_array[1]<190):
        print("The person has in type 2")
    elif(numpy_array[1]>=190):
        print("The person has in type 3")
# Out:
# The person has in type 3
